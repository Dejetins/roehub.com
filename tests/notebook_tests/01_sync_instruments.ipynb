# %%
from apps.cli.commands.sync_instruments import SyncInstrumentsCli

config_path = "/opt/actions-runner/roehub_com/actions-runner/_work/roehub.com/roehub.com/configs/dev/market_data.yaml"
whitelist_path = "/opt/actions-runner/roehub_com/actions-runner/_work/roehub.com/roehub.com/configs/dev/whitelist.csv"

# %%
exit_code = SyncInstrumentsCli().run([
    "--config", config_path,
    "--whitelist", whitelist_path,
    "--report-format", "text",
])
exit_code

# %%
exit_code = SyncInstrumentsCli().run([
    "--config", config_path,
    "--whitelist", whitelist_path,
    "--report-format", "json",
])
exit_code
